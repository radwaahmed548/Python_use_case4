# %%
pip install pandas
import pandas as pd
# Out:
#   Cell In[63], line 1
#     pip install flask_sqlalchemy
#         ^
# SyntaxError: invalid syntax

# %%
pip install lxml
# Out:
# ...
#    ---------------------------------------- 0.0/3.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.9 MB 660.6 kB/s eta 0:00:06
#     --------------------------------------- 0.1/3.9 MB 656.4 kB/s eta 0:00:06
#     --------------------------------------- 0.1/3.9 MB 656.4 kB/s eta 0:00:06
#     --------------------------------------- 0.1/3.9 MB 508.4 kB/s eta 0:00:08
#    - -------------------------------------- 0.1/3.9 MB 504.4 kB/s eta 0:00:08
#    - -------------------------------------- 0.1/3.9 MB 504.4 kB/s eta 0:00:08
#    - -------------------------------------- 0.1/3.9 MB 504.4 kB/s eta 0:00:08
# ...

# %%
pip install pyodbc
# Out:
# ...
#   Using cached pyodbc-5.1.0-cp312-cp312-win_amd64.whl.metadata (2.8 kB)
# Using cached pyodbc-5.1.0-cp312-cp312-win_amd64.whl (69 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df=pd.read_xml(r'D:\projects\use_case_4\doc.xml',xpath='//company/employees/employee[position="Software Engineer"]')
df2=pd.read_xml(r'D:\projects\use_case_4\doc.xml',xpath='//company/employees/employee[position="IT Engineer"]')
df2,df
# Out:
# (     id          name     position   department
#  0     2  Steven Broad  IT Engineer  Engineering
#  1     5    John Smith  IT Engineer  Engineering
#  2     2  Steven Broad  IT Engineer  Engineering
#  3     5    John Smith  IT Engineer  Engineering
#  4     2  Steven Broad  IT Engineer  Engineering
#  ..   ..           ...          ...          ...
#  315   5    John Smith  IT Engineer  Engineering
#  316   2  Steven Broad  IT Engineer  Engineering
#  317   5    John Smith  IT Engineer  Engineering
#  318   2  Steven Broad  IT Engineer  Engineering
#  319   5    John Smith  IT Engineer  Engineering
#
#  [320 rows x 4 columns],
#       id         name           position   department
#  0     1     John Doe  Software Engineer  Engineering
#  1     3  Jane Warner  Software Engineer  Engineering
#  2     4      Ben Doe  Software Engineer  Engineering
#  3     6    Ben Marsh  Software Engineer  Engineering
#  4     7      Jonahan  Software Engineer  Engineering
# ...

# %%
print(df.groupby(['department','id'])['id'].count())
# Out:
# department   id
# Engineering  1       8
#              3     160
#              4     160
#              6     160
#              7       8
#              8       8
# Name: id, dtype: int64

# %%
pip install flask_sqlalchemy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from flask_sqlalchemy import SQLAlchemy

# %%
from sqlalchemy import create_engine

# %%
server = 'BI-R-ABDALLAH'
database = 'MY_DATABASE'
username = 'sa'
password = 'P@ssw0rd@radwa'
driver = 'SQL Server'
conn_str = f'DRIVER={{{driver}}};SERVER={server};DATABASE={database};UID={username};PWD={password}'
engine = create_engine(f"mssql+pyodbc:///?odbc_connect={conn_str}", use_setinputsizes=False)

# %%
df.to_sql("software_engineers", engine, index=False, if_exists='replace')
df2.to_sql("It engineers", engine, index=False, if_exists='replace')
# Out:
# 320
